# %%
import sys
from pathlib import Path

# Add project root so we can import src
project_root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(project_root))

from dotenv import load_dotenv

load_dotenv()

# %%
import src.agents

res = src.agents.frontendDeveloperAgent.invoke({
    "messages": [{"role": "user", "content": "What is the difference between React props and state?"}]
})
print(res["messages"][-1].content)

# %%
import src.agents

res = src.agents.frontendDeveloperAgentLocal.invoke({
    "messages": [{"role": "user", "content": "What is the difference between React props and state?"}]
})
print(res["messages"][-1].content)

# %%
import src.agents

res = src.agents.businessAnalystAgent.invoke({
    "messages": [{"role": "user", "content": "We are a startup that is building a lead management system. The UX is done."}]
})
print(res["messages"][-1].content)
# Out:
# [{'type': 'text', 'text': 'That’s fantastic! Having the UX completed is a significant milestone. What specific areas are you looking for help with next? Whether it’s development, marketing strategies, or user feedback, I’m here to assist!', 'annotations': [], 'id': 'msg_0d19f5ef1e647d87006989e8100ed48196b7fd4733cc3fe556'}]
